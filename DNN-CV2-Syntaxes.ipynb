# %% [markdown]
# # Basic Syntaxes

# %% [markdown]
# ## Loading image from disk to dnn
# ```python
# import cv2
# cv2.dnn.blobFromImage
# cv2.dnn.blobFromImages
# ```

# %% [markdown]
# ## Import model from various framework
# ```python
# import cv2
# cv2.dnn.createCaffeImporter
# cv2.dnn.createTensorFlowImporter
# cv2.dnn.createTorchImporter
# ```
# ## Import the pre-trained models
# ```python
# cv2.dnn.readNetFromCaffe
# cv2.dnn.readnetFromTensorflow
# cv2.dnn.readnetFromTorch
# cv2.dnn.readTorchBlob
# ```

# %% [markdown]
# ### ".forward" is the method used to forward propogate our image and obtain the actual classification.

# %% [markdown]
# ## cv2.dnn.blobFromImage
# Mean subtracted normalized image =
# cv2.dnn.blobFromImage(resizedImage,scalingFactor,Spacial Size,Mean subtraction Values)
#
# blob = cv2.dnn.blobFromImage(imResizeBlob,0.007843,(300,300),127.5)

# %% [markdown]
# # Workflow of DNN in  OpenCV
# 1. Load model
# 2. select backend - Gpu operation
# 3. Select target
# 4. Reading from camera
# 5. convert to blob
# 6. forward
# 7. postprocess - predict the class
# - Usefull for Jetson Nano

# %% [markdown]
# ## Numpy Basic syntax
# 1. arr = np.array([1,2,3,4,5,6])
# 2. Numpy.arrange
#     - numpy.arrange() is one of the array creation routines based on numnerical ranges . it creates an instance of ndarray with evenly spaced values and returns the refernce to it.
#     -  ```python
#     for i in np.arrange(0,detShape):
#     ```
# ![image.png](attachment:image.png)
